# %% [markdown]
# # **House Rent Dataset**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Gather

# %%
df = pd.read_csv(r'C:\Users\ilesannmi\Desktop\Projectssss___\House Rent+ Deployment\House_Rent_Dataset.csv')

# %% [markdown]
# ## Assess

# %%
df.shape
# Out:
# (4746, 12)

# %%
df.head()
# Out:
#     Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1  2022-05-13    2  20000   800       1 out of 3   Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3  2022-07-04    2  10000   800       1 out of 2   Super Area
# 4  2022-05-09    2   7500   850       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner
# ...

# %%
df.columns
# Out:
# Index(['Posted On', 'BHK', 'Rent', 'Size', 'Floor', 'Area Type',
#        'Area Locality', 'City', 'Furnishing Status', 'Tenant Preferred',
#        'Bathroom', 'Point of Contact'],
#       dtype='object')

# %%
df.head().T
# Out:
#                                   0                         1  \
# Posted On                2022-05-18                2022-05-13
# BHK                               2                         2
# Rent                          10000                     20000
# Size                           1100                       800
# Floor               Ground out of 2                1 out of 3
# Area Type                Super Area                Super Area
# Area Locality                Bandel  Phool Bagan, Kankurgachi
# City                        Kolkata                   Kolkata
# Furnishing Status       Unfurnished            Semi-Furnished
# Tenant Preferred   Bachelors/Family          Bachelors/Family
# Bathroom                          2                         1
# Point of Contact      Contact Owner             Contact Owner
#
#                                          2                 3              4
# Posted On                       2022-05-16        2022-07-04     2022-05-09
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   object
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   object
#  5   Area Type          4746 non-null   object
#  6   Area Locality      4746 non-null   object
#  7   City               4746 non-null   object
#  8   Furnishing Status  4746 non-null   object
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   object
# dtypes: int64(4), object(8)
# memory usage: 445.1+ KB

# %%
df.describe()
# Out:
#                BHK          Rent         Size     Bathroom
# count  4746.000000  4.746000e+03  4746.000000  4746.000000
# mean      2.083860  3.499345e+04   967.490729     1.965866
# std       0.832256  7.810641e+04   634.202328     0.884532
# min       1.000000  1.200000e+03    10.000000     1.000000
# 25%       2.000000  1.000000e+04   550.000000     1.000000
# 50%       2.000000  1.600000e+04   850.000000     2.000000
# 75%       3.000000  3.300000e+04  1200.000000     2.000000
# max       6.000000  3.500000e+06  8000.000000    10.000000

# %% [markdown]
# ## Quality

# %% [markdown]
# 1. Posted on should be in dateformat

# %% [markdown]
# ## **Clean**

# %% [markdown]
# ### Define
# 1. Change the Posted_on column to dateformat

# %% [markdown]
# ### Code

# %%
df['Posted On'] = pd.to_datetime(df['Posted On'])

# %% [markdown]
# ### Test

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   datetime64[ns]
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   object
#  5   Area Type          4746 non-null   object
#  6   Area Locality      4746 non-null   object
#  7   City               4746 non-null   object
#  8   Furnishing Status  4746 non-null   object
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   object
# dtypes: datetime64[ns](1), int64(4), object(7)
# memory usage: 445.1+ KB

# %% [markdown]
# # **Exploraton**

# %%
df.head()
# Out:
#    Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0 2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1 2022-05-13    2  20000   800       1 out of 3   Super Area
# 2 2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3 2022-07-04    2  10000   800       1 out of 2   Super Area
# 4 2022-05-09    2   7500   850       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner
# ...

# %% [markdown]
# ### hOW many cities are in the dataset

# %%
df.City.value_counts()
# Out:
# Mumbai       972
# Chennai      891
# Bangalore    886
# Hyderabad    868
# Delhi        605
# Kolkata      524
# Name: City, dtype: int64

# %%
plt.figure(figsize=(12,8))

df.City.value_counts().plot(kind = 'bar', fontsize = 20)
plt.title('Plots showing the Cities in the dataset', fontsize = 20)
plt.show()

# %% [markdown]
# #### Observation: Mumbai appears most in the dataset and the lovest are Delhi and Kolkata

# %%
df['Area Locality'].value_counts()
# Out:
# Bandra West                                37
# Gachibowli                                 29
# Electronic City                            24
# Velachery                                  22
# Miyapur, NH 9                              22
#                                            ..
# Kengeri Upanagara                           1
# Ittamadu, Banashankari, Outer Ring Road     1
# Rmv Extension, Armane Nagar                 1
# snv la                                      1
# Manikonda, Hyderabad                        1
# Name: Area Locality, Length: 2235, dtype: int64

# %% [markdown]
# ## What are the status?

# %%
df['Furnishing Status'].value_counts()
# Out:
# Semi-Furnished    2251
# Unfurnished       1815
# Furnished          680
# Name: Furnishing Status, dtype: int64

# %%
plt.figure(figsize=(12,8))
df['Furnishing Status'].value_counts().plot(kind='bar', fontsize=20)
plt.title('Furnishing status of houses', fontsize=20)
plt.show()

# %% [markdown]
# #### Obseravation: Most of the houses in the dataset are Semi-Furnished. This means that most rented houses are partially furnished and least of Furnished houses are Rented

# %% [markdown]
# ## Area Type of the Rented Apartments

# %%
df['Area Type'].value_counts()
# Out:
# Super Area     2446
# Carpet Area    2298
# Built Area        2
# Name: Area Type, dtype: int64

# %%
plt.figure(figsize=(12,8))
df['Area Type'].value_counts().plot(kind='bar', fontsize=20)
plt.title('Area type of the Houses', fontsize=20)
plt.show()

# %% [markdown]
# Moat of the rented apartments are the Super area, which is the Carpet Area + Built Area

# %%
df.head()
# Out:
#    Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0 2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1 2022-05-13    2  20000   800       1 out of 3   Super Area
# 2 2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3 2022-07-04    2  10000   800       1 out of 2   Super Area
# 4 2022-05-09    2   7500   850       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner
# ...

# %% [markdown]
# ## What kind of Tenant is preferred?

# %%
df['Tenant Preferred'].value_counts()
# Out:
# Bachelors/Family    3444
# Bachelors            830
# Family               472
# Name: Tenant Preferred, dtype: int64

# %%
plt.figure(figsize=(12,8))

df['Tenant Preferred'].value_counts().plot(kind='bar', fontsize=20)
plt.title('Preferred Tenants Status', fontsize=20)
plt.show()

# %% [markdown]
# ### Observation: Many dont mind the marital status

# %% [markdown]
# # **Correlations**

# %%
df.corr()
# Out:
#                BHK      Rent      Size  Bathroom
# BHK       1.000000  0.369718  0.716145  0.794885
# Rent      0.369718  1.000000  0.413551  0.441215
# Size      0.716145  0.413551  1.000000  0.740703
# Bathroom  0.794885  0.441215  0.740703  1.000000

# %%
plt.figure(figsize=(12,8))

sns.heatmap(df.corr(), cmap='Blues', annot =True, annot_kws={'fontsize':16, 'fontweight':'bold'})
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Observation: There's a good correlation between rent and Bathroom
#
# Bedrooom, hall and kitchen has less correlation with rent price

# %% [markdown]
# ## Correlatio between Rent and BHK?

# %%
plt.figure(figsize=(12,8))

plt.scatter(df['BHK'], df['Rent'])
plt.title('Correlation between Rent and BHK', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Correlation between Rent and BHK')

# %% [markdown]
# ### Observation: There's  no real correlation between Rent Prices and the size of Bedroom, Hall and Kitchen

# %% [markdown]
# ## Correlatio between number of bathroom and Rent price

# %%
plt.figure(figsize=(12,8))

plt.scatter(df['Bathroom'], df['Rent'])
plt.title('Correlation between Rent and number of Bathroom', fontsize=20)
plt.show()

# %%
plt.figure(figsize=(12,8))

df['Bathroom'].value_counts().plot(kind='bar', fontsize=20)
plt.title('Number of Bathroom', fontsize=20)
plt.show()

# %% [markdown]
# ### Observation: Most houses just uses 2 bathrooms

# %% [markdown]
# ## What is the most common point of contact?

# %%
plt.figure(figsize=(12,8))

df['Point of Contact'].value_counts().plot(kind='bar', fontsize=20)
plt.title('Point of Contact', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Point of Contact')

# %%
df['Floor'].value_counts().nlargest(10)
# Out:
# 1 out of 2         379
# Ground out of 2    350
# 2 out of 3         312
# 2 out of 4         308
# 1 out of 3         293
# 3 out of 4         239
# Ground out of 3    209
# 1 out of 4         200
# Ground out of 1    195
# 1 out of 1         134
# Name: Floor, dtype: int64

# %%
#Dropping the Floor coluumn

df = df.drop('Floor', axis = 1)

# %% [markdown]
# # **Encoding**

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()

# %%
y = 'Rent'
features = df.drop(y, axis = 1)
target = df[y].values
features_encoded = features.apply(enc.fit_transform)

# %%
print(features_encoded)
# Out:
#       Posted On  BHK  Size  Area Type  Area Locality  City  Furnishing Status  \
# 0            26    1   334          2            221     4                  2
# 1            21    1   223          2           1527     4                  1
# 2            24    1   302          2           1760     4                  1
# 3            73    1   223          2            526     4                  2
# 4            17    1   243          1           1890     4                  2
# ...         ...  ...   ...        ...            ...   ...                ...
# 4741         26    1   302          1            219     3                  1
# 4742         23    2   529          2           1214     3                  1
# 4743         79    2   491          1            724     3                  1
# 4744         75    2   446          1            590     3                  1
# 4745         12    1   302          1           1915     3                  2
#
# ...

# %%
target
# Out:
# array([10000, 20000, 17000, ..., 35000, 45000, 15000], dtype=int64)

# %% [markdown]
# # Train-Test split

# %%
from sklearn.model_selection import train_test_split

# %%
x_tr, x_test, y_tr, y_test = train_test_split(features_encoded, target, random_state = 30)

# %%
sns.pairplot(df )

# %% [markdown]
# # Model

# %% [markdown]
# ## *Lasso Regression*

# %%
from sklearn.linear_model import Lasso

# %%
def Lasso_regression_model( x_tr, x_te, y_tr, y_te, C = 1.0):
    las = Lasso(alpha= C)
    las.fit(x_tr, y_tr)
    print('training accuracy: ', las.score(x_tr, y_tr))
    print('testing accuracy: ', las.score(x_te, y_te))
    
    return las

# %%
Lasso_regression_model( x_tr, x_test, y_tr, y_test, C = 1.0)
# Out:
# training accuracy:  0.2212393932409279
# testing accuracy:  0.43533989111063043
# Lasso()

# %% [markdown]
# # *Ridge Regression*

# %%
from sklearn.linear_model import Ridge

# %%
def Ridge_regression_model( x_tr, x_te, y_tr, y_te, C = 1.0):
    rid = Ridge(alpha= C)
    rid.fit(x_tr, y_tr)
    print('training accuracy: ', rid.score(x_tr, y_tr))
    print('testing accuracy: ', rid.score(x_te, y_te))
    
    return rid

# %%
Ridge_regression_model( x_tr, x_test, y_tr, y_test, C = 1.0)
# Out:
# training accuracy:  0.2212393704860417
# testing accuracy:  0.43532589693204593
# Ridge()

# %% [markdown]
# # *Linear Regression*

# %%
from sklearn.linear_model import LinearRegression
ln = LinearRegression()
ln = ln.fit(x_tr, y_tr)

pred = ln.predict(x_test)
print('training accuracy: ', ln.score(x_tr, y_tr))

print('testing accuracy: ', ln.score(x_test, y_test))
# Out:
# training accuracy:  0.22123939502205348
# testing accuracy:  0.4353393758049313

# %% [markdown]
# # *RandomForest*

# %%
from sklearn.ensemble import RandomForestRegressor

def RandomFR_model():
    regr = RandomForestRegressor(max_depth=3, random_state=25)
    regr.fit(x_tr, y_tr)

    print('training accuracy: ', regr.score(x_tr, y_tr))

    print('testing accuracy: ', regr.score(x_test, y_test))
    return regr

# pred = regr.predict(x_test)
# print(pred)
regr = RandomFR_model()
# Out:
# training accuracy:  0.5693072828966026
# testing accuracy:  0.5987190917649625

# %% [markdown]
# # *Decision Tree*

# %%
from sklearn import tree

tree = tree.DecisionTreeRegressor()
tree.fit(x_tr, y_tr)

print('training accuracy: ', tree.score(x_tr, y_tr))

print('testing accuracy: ', tree.score(x_test, y_test))
# Out:
# training accuracy:  0.9999816739435308
# testing accuracy:  -4.186672006580828

# %% [markdown]
# Testing accuracy giving a negative value shows the model is not right for the dataset

# %% [markdown]
# # *KNN*

# %%
from sklearn.neighbors import KNeighborsRegressor

neigh = KNeighborsRegressor(n_neighbors=10)
neigh.fit(x_tr, y_tr)

print('training accuracy: ', neigh.score(x_tr, y_tr))

print('testing accuracy: ', neigh.score(x_test, y_test))
# Out:
# training accuracy:  0.27233051058005087
# testing accuracy:  0.26526040757474767

# %% [markdown]
# # *Saving Model*

# %% [markdown]
# ### Feature Selection for deployment

# %%
# bathroom,
# Size of the Houses/Apartments/Flats in Square Feet.
# city
# BHK: Number of Bedrooms, Hall, Kitchen.

df.head()
# Out:
#    Posted On  BHK   Rent  Size    Area Type             Area Locality  \
# 0 2022-05-18    2  10000  1100   Super Area                    Bandel
# 1 2022-05-13    2  20000   800   Super Area  Phool Bagan, Kankurgachi
# 2 2022-05-16    2  17000  1000   Super Area   Salt Lake City Sector 2
# 3 2022-07-04    2  10000   800   Super Area               Dumdum Park
# 4 2022-05-09    2   7500   850  Carpet Area             South Dum Dum
#
#       City Furnishing Status  Tenant Preferred  Bathroom Point of Contact
# 0  Kolkata       Unfurnished  Bachelors/Family         2    Contact Owner
# 1  Kolkata    Semi-Furnished  Bachelors/Family         1    Contact Owner
# 2  Kolkata    Semi-Furnished  Bachelors/Family         1    Contact Owner
# 3  Kolkata       Unfurnished  Bachelors/Family         1    Contact Owner
# 4  Kolkata       Unfurnished         Bachelors         1    Contact Owner

# %%
df_FT = df

feat = ['BHK', 'City', 'Bathroom', 'Size']
y = 'Rent'
features = df_FT[feat]
target = df_FT[y].values


### Encoding the city column alone
City_enc = features[['City']].apply(enc.fit_transform)

features['city_enc'] = City_enc
# Out:
# C:\Users\ilesannmi\AppData\Local\Temp\ipykernel_12816\2605355187.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features['city_enc'] = City_enc

# %%
features.head()
# Out:
#    BHK     City  Bathroom  Size  city_enc
# 0    2  Kolkata         2  1100         4
# 1    2  Kolkata         1   800         4
# 2    2  Kolkata         1  1000         4
# 3    2  Kolkata         1   800         4
# 4    2  Kolkata         1   850         4

# %%
features2 = features.drop('City', axis= 1)

# %%
features2['city_enc'].value_counts(), features['City'].value_counts()
# Out:
# (5    972
#  1    891
#  0    886
#  3    868
#  2    605
#  4    524
#  Name: city_enc, dtype: int64,
#  Mumbai       972
#  Chennai      891
#  Bangalore    886
#  Hyderabad    868
#  Delhi        605
#  Kolkata      524
#  Name: City, dtype: int64)

# %%
features2
# Out:
#       BHK  Bathroom  Size  city_enc
# 0       2         2  1100         4
# 1       2         1   800         4
# 2       2         1  1000         4
# 3       2         1   800         4
# 4       2         1   850         4
# ...   ...       ...   ...       ...
# 4741    2         2  1000         3
# 4742    3         3  2000         3
# 4743    3         3  1750         3
# 4744    3         2  1500         3
# 4745    2         2  1000         3
#
# [4746 rows x 4 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(features2, target, random_state = 15)

# %%
def RandomFR_model(x_train, x_test, y_train, y_test):
    regr = RandomForestRegressor(max_depth=3, random_state=25)
    regr.fit(x_train, y_train)

    print('training accuracy: ', regr.score(x_train, y_train))

    print('testing accuracy: ', regr.score(x_test, y_test))
    return regr

# pred = regr.predict(x_test)
# print(pred)
FT = RandomFR_model(x_train, x_test, y_train, y_test)
# Out:
# training accuracy:  0.5146013299174919
# testing accuracy:  0.6742825980737704

# %%
import pickle

pickle_out = open('modelmodel2.pkl', mode = 'wb')
pickle.dump(FT, pickle_out)
pickle_out.close()

# %%
pickle_in = open('modelmodel2.pkl', 'rb')
clf = pickle.load(pickle_in)

# %%
features2.head()
# Out:
#    BHK  Bathroom  Size  city_enc
# 0    2         2  1100         4
# 1    2         1   800         4
# 2    2         1  1000         4
# 3    2         1   800         4
# 4    2         1   850         4

# %%
print(clf.predict([[6, 5, 2000, 0]]))
# Out:
# [67102.50659194]
# c:\Users\ilesannmi\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # *Building into a WEB app with STREAMLIT*

# %%
# !pip install -q pyngrok
# !pip install -q streamlit
# !pip install -q streamlit_ace
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.2.2 requires pyqt5<5.13, which is not installed.
# spyder 5.2.2 requires pyqtwebengine<5.13, which is not installed.

# %%
# %%writefile app.py

import pickle
import streamlit as st

pickle_in = open('modelmodel2.pkl', 'rb')

clf = pickle.load(pickle_in)


@st.cache()

def make_prediction(bhk, Bathroom, Size, City):
    if City == 'Mumbai':
        city_enc = 5
    elif City == 'Chennai':
        city_enc = 1
    elif City == 'Bangalore':
        city_enc = 0
    elif City == 'Hyderabad':
        city_enc = 3
    elif City == 'Delhi':
        city_enc = 2
    elif City == 'Kolkata':
        city_enc = 4
    
    prediction = clf.predict([[bhk, Bathroom, Size, city_enc]])[0]
    return prediction


def main():
    #front end elements
    html_temp = """
    <div style = "background-color:green;padding:13px">
    <h1 style = "color:blue;text-align:center;"> House Prices Prediction by Ilesanmi </h1>
    </div>
    """

    #front end 
    #st.markdown("![](https://miro.medium.com/max/640/1*D6s2K1y7kjE14swcgITB1w.png)")
    
    st.markdown(html_temp, unsafe_allow_html = True)

    #following lines create the visuals
    City = st.selectbox('City', ('Mumbai','Chennai','Bangalore','Hyderabad','Delhi','Kolkata'))    
    Bathroom = st.number_input('Enter number of Bathroom')
    Size = st.number_input('Enter Size of the Land')
    bhk = st.number_input('Enter number of BHK')

    #when 'predict' is clicked, make prediction
    if st.button('Make Prediction'):
        result = make_prediction(bhk, Bathroom, Size, City)
        st.success('The price is mostlikely: {}'.format(result))
        print('Just test')

if __name__ == '__main__':
    main()
# Out:
# Overwriting app.py

# %%
plt.figure(figsize=(15,12))

sns.heatmap(df_encoded.corr(), cmap='Blues', annot =True, annot_kws={'fontsize':16, 'fontweight':'bold'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12816\1906058457.py in <module>
#       1 plt.figure(figsize=(15,12))
#       2
# ----> 3 sns.heatmap(df_encoded.corr(), cmap='Blues', annot =True, annot_kws={'fontsize':16, 'fontweight':'bold'})
#
# NameError: name 'df_encoded' is not defined

# %%
plt.figure(figsize=(12,8))

sns.heatmap(features_encoded.corr(), cmap='Blues', annot =True, annot_kws={'fontsize':16, 'fontweight':'bold'})
# Out:
# <AxesSubplot:>

# %%
bathroom,
Size of the Houses/Apartments/Flats in Square Feet.
city
BHK: Number of Bedrooms, Hall, Kitchen.

# %%
df.head()
# Out:
#    Posted On  BHK   Rent  Size    Area Type             Area Locality  \
# 0 2022-05-18    2  10000  1100   Super Area                    Bandel
# 1 2022-05-13    2  20000   800   Super Area  Phool Bagan, Kankurgachi
# 2 2022-05-16    2  17000  1000   Super Area   Salt Lake City Sector 2
# 3 2022-07-04    2  10000   800   Super Area               Dumdum Park
# 4 2022-05-09    2   7500   850  Carpet Area             South Dum Dum
#
#       City Furnishing Status  Tenant Preferred  Bathroom Point of Contact
# 0  Kolkata       Unfurnished  Bachelors/Family         2    Contact Owner
# 1  Kolkata    Semi-Furnished  Bachelors/Family         1    Contact Owner
# 2  Kolkata    Semi-Furnished  Bachelors/Family         1    Contact Owner
# 3  Kolkata       Unfurnished  Bachelors/Family         1    Contact Owner
# 4  Kolkata       Unfurnished         Bachelors         1    Contact Owner

# %%
df.BHK.value_counts()
# Out:
# 2    2265
# 1    1167
# 3    1098
# 4     189
# 5      19
# 6       8
# Name: BHK, dtype: int64

# %%
df.City.value_counts()
# Out:
# Mumbai       972
# Chennai      891
# Bangalore    886
# Hyderabad    868
# Delhi        605
# Kolkata      524
# Name: City, dtype: int64
